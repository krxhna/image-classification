# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# /import seaborn as sns
import random

# %%
list =[]
for i in range(1000):
    r = random.randint(0,100)
    list.append(r)

# %%
t=[]
for i in range(1000):
    t.append(i)

# %%
plt.scatter(list,t)
